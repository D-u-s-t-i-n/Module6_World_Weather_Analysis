# %% [markdown]
# # Module 6 Challenge - Part 2

# %%
# %matplotlib inline
# %matplotlib notebook
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np
# Import the API key.
from config import g_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

Weather_df = pd.read_csv("WeatherPy_challenge.csv")
Weather_df
# Out:
#     Unnamed: 0                 City    Lat     Lng  Max Temp  Humidity %  \
# 0            0              Rikitea -23.12 -134.97     78.85          78
# 1            1            Hithadhoo  -0.60   73.08     83.34          78
# 2            2         Kudahuvadhoo   2.67   72.89     82.67          70
# 3            3          Santa Maria -29.68  -53.81     71.60          94
# 4            4       Puerto Carreno   6.19  -67.49     77.29          81
# 5            5             Tasiilaq  65.61  -37.64     21.20          85
# 6            6                Alofi -19.06 -169.92     82.40          69
# 7            7              Dolores -36.31  -57.68     57.09          92
# 8            8               Atuona  -9.80 -139.03     81.72          81
# 9            9                Vaini -21.20 -175.20     78.80          83
# 10          10             Olafsvik  64.89  -23.71     32.16          66
# 11          11                 Asau  46.43   26.40     45.00          75
# 12          12  Gorzow Wielkopolski  52.74   15.23     39.99          67
#
#     Cloudiness %  Wind Speed (mph)           Weather Country  RainFall (in.)  \
# 0              1             14.81         clear sky      PF            0.00
# 1              9             13.09        light rain      MV            0.75
# 2             58             19.73     broken clouds      MV            0.00
# 3             40              3.36  scattered clouds      BR            0.00
# 4             65              4.85     broken clouds      CO            0.00
# 5            100             25.28        light snow      GL            0.00
# 6             23              9.17        few clouds      NU            0.00
# 7              0              4.09         clear sky      AR            0.00
# 8             54             20.80        light rain      PF            0.19
# 9             40              9.17  scattered clouds      TO            0.00
# 10            51             11.59        light snow      IS            0.00
# 11            90              6.93   overcast clouds      RO            0.00
# 12            87              5.01   overcast clouds      PL            0.00
#
#     SnowFall (in.)                 Date
# 0             0.00  2020-02-19 04:31:59
# 1             0.00  2020-02-19 04:32:00
# 2             0.00  2020-02-19 04:32:00
# 3             0.00  2020-02-19 04:32:00
# 4             0.00  2020-02-19 04:30:08
# 5             0.00  2020-02-19 04:32:01
# 6             0.00  2020-02-19 04:32:01
# 7             0.00  2020-02-19 04:32:01
# 8             0.00  2020-02-19 04:32:01
# 9             0.00  2020-02-19 04:32:02
# 10            0.19  2020-02-19 04:32:02
# 11            0.00  2020-02-19 04:32:02
# 12            0.00  2020-02-19 04:28:31

# %%
##### Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
yesno_snow = string(input("Do you want it to be snowing? "))
yesno_rain = string(input("Do you want it to be raining? "))

# %%
max_temp = Weather_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
#max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Filter the dataset to find the cities that fit the criteria.
min_temp = 75
max_temp = 90
min_snow = 0
min_rain = 0
yesno_snow = "yEs"
yesno_rain = "yes"
if (yesno_rain.lower() == "yes") & (yesno_snow.lower() == "yes"):
    print("debug1")
    preferred_cities_df = Weather_df.loc[(Weather_df["Max Temp"] <= max_temp) & \
                                       (Weather_df["Max Temp"] >= min_temp) & \
                                        (Weather_df["SnowFall (in.)"] > 0) & \
                                        (Weather_df["RainFall (in.)"] > 0)]
elif (yesno_rain.lower() == "yes") & (yesno_snow.lower() == "no"):
    print("debug2")
    preferred_cities_df = Weather_df.loc[(Weather_df["Max Temp"] <= max_temp) & \
                                       (Weather_df["Max Temp"] >= min_temp) & \
                                        (Weather_df["SnowFall (in.)"] == 0) & \
                                        (Weather_df["RainFall (in.)"] > 0)]
elif (yesno_rain.lower() == "no") & (yesno_snow.lower() == "yes"):
    print("debug3")
    preferred_cities_df = Weather_df.loc[(Weather_df["Max Temp"] <= max_temp) & \
                                       (Weather_df["Max Temp"] >= min_temp) & \
                                        (Weather_df["SnowFall (in.)"] > 0) & \
                                        (Weather_df["RainFall (in.)"] == 0)]
else:
    print("debug4")
    preferred_cities_df = Weather_df.loc[(Weather_df["Max Temp"] <= max_temp) & \
                                       (Weather_df["Max Temp"] >= min_temp) & \
                                        (Weather_df["SnowFall (in.)"] == 0) & \
                                        (Weather_df["RainFall (in.)"] == 0)]
preferred_cities_df.head(10)
# Out:
# debug4
#    Unnamed: 0            City    Lat     Lng  Max Temp  Humidity %  \
# 0           0         Rikitea -23.12 -134.97     78.85          78
# 2           2    Kudahuvadhoo   2.67   72.89     82.67          70
# 4           4  Puerto Carreno   6.19  -67.49     77.29          81
# 6           6           Alofi -19.06 -169.92     82.40          69
# 9           9           Vaini -21.20 -175.20     78.80          83
#
#    Cloudiness %  Wind Speed (mph)           Weather Country  RainFall (in.)  \
# 0             1             14.81         clear sky      PF             0.0
# 2            58             19.73     broken clouds      MV             0.0
# 4            65              4.85     broken clouds      CO             0.0
# 6            23              9.17        few clouds      NU             0.0
# 9            40              9.17  scattered clouds      TO             0.0
#
#    SnowFall (in.)                 Date
# 0             0.0  2020-02-19 04:31:59
# 2             0.0  2020-02-19 04:32:00
# 4             0.0  2020-02-19 04:30:08
# 6             0.0  2020-02-19 04:32:01
# 9             0.0  2020-02-19 04:32:02

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
#hotel_df = preferred_cities_df[["City", "Country", "Weather", "Max Temp", "Lat", "Lng"]].copy()
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description","Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country           Weather  Max Temp    Lat     Lng  \
# 0         Rikitea      PF         clear sky     78.85 -23.12 -134.97
# 2    Kudahuvadhoo      MV     broken clouds     82.67   2.67   72.89
# 4  Puerto Carreno      CO     broken clouds     77.29   6.19  -67.49
# 6           Alofi      NU        few clouds     82.40 -19.06 -169.92
# 9           Vaini      TO  scattered clouds     78.80 -21.20 -175.20
#
#   Hotel Name
# 0
# 2
# 4
# 6
# 9

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Weather} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
hotel_info
# Out:
# ["\n<dl>\n<dt>Hotel Name</dt><dd>Pension Maro'i</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Weather</dt><dd>clear sky and 78.85 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kudahuvadhoo Retreat</dd>\n<dt>City</dt><dd>Kudahuvadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>broken clouds and 82.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Hotel Victoria</dd>\n<dt>City</dt><dd>Puerto Carreno</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Weather</dt><dd>broken clouds and 77.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Current Weather</dt><dd>few clouds and 82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Current Weather</dt><dd>scattered clouds and 78.8 °F</dd>\n</dl>\n']

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
file_name = "WeatherPy_vacation.csv"
hotel_df.to_csv(file_name)

# %%
hotel_df
# Out:
#              City Country           Weather  Max Temp    Lat     Lng  \
# 0         Rikitea      PF         clear sky     78.85 -23.12 -134.97
# 2    Kudahuvadhoo      MV     broken clouds     82.67   2.67   72.89
# 4  Puerto Carreno      CO     broken clouds     77.29   6.19  -67.49
# 6           Alofi      NU        few clouds     82.40 -19.06 -169.92
# 9           Vaini      TO  scattered clouds     78.80 -21.20 -175.20
#
#              Hotel Name
# 0        Pension Maro'i
# 2  Kudahuvadhoo Retreat
# 4   Casa Hotel Victoria
# 6         Taloa Heights
# 9   Keleti Beach Resort
